# %%
# Methods Modifying Properties


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def birthday(self):
        self.age += 1
        print(f"Happy Birthday! You are now {self.age}")


p1 = Person("Ovi", 27)
p1.birthday()
p1.birthday()
p1.birthday()
p1.birthday()

p2 = Person("Ovi", 17)
p2.birthday()
p2.birthday()
# Out:
# Happy Birthday! You are now 28
# Happy Birthday! You are now 29
# Happy Birthday! You are now 30
# Happy Birthday! You are now 31
# Happy Birthday! You are now 18
# Happy Birthday! You are now 19

# %%
class Person:
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary

p1 = Person('Ovi',65000)
print(p1.name,p1.__salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4         self.__salary=salary
#       6 p1 = Person('Ovi',65000)
# ----> 7 print(p1.name,p1.__salary)
#
# AttributeError: 'Person' object has no attribute '__salary'
